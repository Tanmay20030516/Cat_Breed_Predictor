# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import os # accessing file systems
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
import cv2
import numpy as np

# %%
# class_list = os.listdir("/kaggle/input/cat-breed-images/actually_used_data")
# print(class_list)
class_list = ['bengal_cat','bombay_cat','himalayan_cat','persian_cat']
print(class_list)
# Out:
# ['bengal_cat', 'bombay_cat', 'himalayan_cat', 'persian_cat']

# %%
# controlling the use of gpu memory
# gpus = tf.config.experimental.list_physical_devices("GPU")
# for gpu in gpus:
#     tf.config.experimental.set_memory_growth(gpu, True)

# %%
# gpus

# %%
sample_img = cv2.imread(os.path.join("/kaggle/input/cat-breed-dataset/actually_used_data/actually_used_data", "bombay_cat", "bombay_cat60.jpg"))
plt.imshow(cv2.cvtColor(sample_img, cv2.COLOR_BGR2RGB)) # openCV reads as BGR and not RGB

# %% [markdown]
# ## Loading the dataset

# %%
# tf.keras.utils.image_dataset_from_directory??

# %%
data = tf.keras.utils.image_dataset_from_directory("/kaggle/input/cat-breed-dataset/actually_used_data/actually_used_data",
                                                   batch_size=32,
                                                   class_names=class_list
                                                   )
# builds the dataset by labeling the images, resizing the images and even batching the images
# Out:
# Found 4000 files belonging to 4 classes.

# %%
data_iterator = data.as_numpy_iterator()
batch = data_iterator.next()
print(batch[0].shape, batch[1].shape)
# Out:
# (32, 256, 256, 3) (32,)

# %%
batch[1]
# 0 - bengal
# 1 - bombay
# 2 - himalayan
# 3 - persian
# Out:
# array([3, 1, 0, 1, 0, 3, 2, 2, 3, 3, 3, 2, 2, 2, 0, 3, 0, 1, 0, 0, 1, 2,
#        1, 3, 2, 0, 1, 2, 2, 3, 2, 0], dtype=int32)

# %%
# know the current batch
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]): # 1st 4 images of current batch
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

plt.show()

# %% [markdown]
# ## Data Augmentation

# %%
# !pip install albumentations
# Out:
# Requirement already satisfied: albumentations in /opt/conda/lib/python3.10/site-packages (1.3.1)
# Requirement already satisfied: numpy>=1.11.1 in /opt/conda/lib/python3.10/site-packages (from albumentations) (1.23.5)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from albumentations) (1.11.1)
# Requirement already satisfied: scikit-image>=0.16.1 in /opt/conda/lib/python3.10/site-packages (from albumentations) (0.21.0)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from albumentations) (6.0)
# Requirement already satisfied: qudida>=0.0.4 in /opt/conda/lib/python3.10/site-packages (from albumentations) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from albumentations) (4.8.0.74)
# Requirement already satisfied: scikit-learn>=0.19.1 in /opt/conda/lib/python3.10/site-packages (from qudida>=0.0.4->albumentations) (1.2.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from qudida>=0.0.4->albumentations) (4.6.3)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations) (9.5.0)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations) (1.4.1)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations) (21.3)
# Requirement already satisfied: lazy_loader>=0.2 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations) (0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=21->scikit-image>=0.16.1->albumentations) (3.0.9)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (3.1.0)

# %%
import albumentations as album

# %%
augmentor = album.Compose([ # augmented image size
                         album.HorizontalFlip(p=0.5), 
                         album.RandomBrightnessContrast(p=0.5),
                         album.RandomGamma(p=0.5), 
                         album.RGBShift(p=0.5), 
                         album.VerticalFlip(p=0.5)])

# %%
sample_image = cv2.imread("/kaggle/input/cat-breed-dataset/actually_used_data/actually_used_data/himalayan_cat/1.jpg")
augmented = augmentor(image=sample_image)
plt.imshow(cv2.cvtColor(augmented['image'], cv2.COLOR_BGR2RGB))
# augmented

# %%
os.mkdir('/kaggle/working/aug_data/')
for partition in ['bengal_cat','bombay_cat','himalayan_cat','persian_cat']:
    os.mkdir(f"/kaggle/working/aug_data/{partition}/")

# %%
for partition in ['bengal_cat','bombay_cat','himalayan_cat','persian_cat']: 
    for image in os.listdir(os.path.join('/kaggle/input/cat-breed-dataset/actually_used_data/actually_used_data', partition)):
        img = cv2.imread(os.path.join('/kaggle/input/cat-breed-dataset/actually_used_data/actually_used_data', partition, image)) # reading image in a partition
        try: 
            for x in range(10): # 10 augmented images for each image passed
                augmented = augmentor(image=img)
                cv2.imwrite(os.path.join('/kaggle/working/aug_data/', partition, f'{image.split(".")[0]}.{x}.jpg'), augmented['image'])

        except Exception as e:
            print(e) # print the error, rather than just stopping the cell execution

# %%
final_data = tf.keras.utils.image_dataset_from_directory("/kaggle/working/aug_data",
                                                   batch_size=32,
                                                   class_names=class_list
                                                   )
# Out:
# Found 40000 files belonging to 4 classes.

# %% [markdown]
# So we were able to increase the dataset size by **10 times**.

# %% [markdown]
# ## Preprocess the data

# %%
# scale the data
final_data = final_data.map(lambda x, y: (x/255.0, y)) # x=pixel values and y=label

# %%
new_batch = final_data.as_numpy_iterator().next()

fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(new_batch[0][:4]): # 1st 4 images of current batch
    ax[idx].imshow(img)
    ax[idx].title.set_text(new_batch[1][idx])

plt.show()

# note that the pixel values values are now between 0. and 1.

# %% [markdown]
# ## Train-Test-Validation Split

# %%
len(final_data) # number of batches
# Out:
# 1250

# %%
train_size = int(len(final_data)*0.7)
val_size = int(len(final_data)*0.2)
test_size = int(len(final_data)*0.1)
print(train_size+val_size+test_size) # = 1250 is a must
# Out:
# 1250

# %%
# split the data
train = final_data.take(train_size) # tf method to take amount of data
val = final_data.skip(train_size).take(val_size)
test = final_data.skip(train_size+val_size).take(test_size)

# %%
len(train), len(val), len(test) # number of batches
# Out:
# (875, 250, 125)

# %% [markdown]
# ## Using Keras sequential API for creating the model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, GlobalMaxPooling2D, Dropout

# %%
model = Sequential()

# Convolution block 1
model.add(Conv2D(filters=32, kernel_size=(3,3), input_shape=(256,256,3)))
model.add(MaxPooling2D())

# Convolution block 2
model.add(Conv2D(filters=32, kernel_size=(3,3), padding="same"))

# Convolution block 3
model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same"))
model.add(MaxPooling2D())

# Convolution block 4
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same"))
model.add(MaxPooling2D())

# Convolution block 5
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same"))
model.add(MaxPooling2D())

# model.add(Flatten())
model.add(GlobalMaxPooling2D())

# fully connected layers
model.add(Dense(512, activation="relu", kernel_initializer="he_normal"))
model.add(Dropout(0.5))
model.add(Dense(512, activation="relu", kernel_initializer="he_normal"))
model.add(Dropout(0.5))
model.add(Dense(512, activation="relu", kernel_initializer="he_normal"))
model.add(Dropout(0.5))

model.add(Dense(4, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 127, 127, 32)      9248
#
#  conv2d_2 (Conv2D)           (None, 127, 127, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 63, 63, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 63, 63, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 31, 31, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 31, 31, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 15, 15, 256)      0
#  2D)
#
#  global_max_pooling2d (Globa  (None, 256)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 512)               131584
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 1,056,612
# Trainable params: 1,056,612
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss="sparse_categorical_crossentropy", # multiclass classification
    metrics=["accuracy"]
)

# %%
logdir = "/kaggle/working/logs_dir"
# directory where all the model training stages (checkpoints) will be added

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# best model will be stored, which performed best on validation set
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint("/kaggle/working/model/cat_breed_classifier_best_model.h5",save_best_only=True)

# %%
model_history = model.fit(train, epochs=40, validation_data=val, callbacks=[tensorboard_callback, checkpoint_callback])
# Out:
# Epoch 1/40
# 875/875 [==============================] - 136s 141ms/step - loss: 1.2318 - accuracy: 0.4076 - val_loss: 1.0381 - val_accuracy: 0.5564
# Epoch 2/40
# 875/875 [==============================] - 152s 173ms/step - loss: 0.9129 - accuracy: 0.6163 - val_loss: 0.6906 - val_accuracy: 0.7287
# Epoch 3/40
# 875/875 [==============================] - 146s 166ms/step - loss: 0.6750 - accuracy: 0.7318 - val_loss: 0.5030 - val_accuracy: 0.7974
# Epoch 4/40
# 875/875 [==============================] - 146s 166ms/step - loss: 0.5320 - accuracy: 0.7943 - val_loss: 0.5322 - val_accuracy: 0.7961
# Epoch 5/40
# 875/875 [==============================] - 147s 167ms/step - loss: 0.4711 - accuracy: 0.8231 - val_loss: 0.4224 - val_accuracy: 0.8461
# Epoch 6/40
# 875/875 [==============================] - 132s 150ms/step - loss: 0.3951 - accuracy: 0.8534 - val_loss: 0.4654 - val_accuracy: 0.8259
# Epoch 7/40
# 875/875 [==============================] - 146s 167ms/step - loss: 0.3452 - accuracy: 0.8769 - val_loss: 0.5257 - val_accuracy: 0.8484
# Epoch 8/40
# 875/875 [==============================] - 147s 167ms/step - loss: 0.3124 - accuracy: 0.8921 - val_loss: 0.3194 - val_accuracy: 0.8929
# Epoch 9/40
# 875/875 [==============================] - 122s 139ms/step - loss: 0.2810 - accuracy: 0.9058 - val_loss: 0.3307 - val_accuracy: 0.9011
# Epoch 10/40
# 875/875 [==============================] - 154s 175ms/step - loss: 0.2519 - accuracy: 0.9179 - val_loss: 0.4065 - val_accuracy: 0.8449
# Epoch 11/40
# 875/875 [==============================] - 146s 166ms/step - loss: 0.2563 - accuracy: 0.9185 - val_loss: 0.4208 - val_accuracy: 0.8485
# Epoch 12/40
# 875/875 [==============================] - 156s 178ms/step - loss: 0.2361 - accuracy: 0.9281 - val_loss: 0.2820 - val_accuracy: 0.9024
# Epoch 13/40
# 875/875 [==============================] - 125s 142ms/step - loss: 0.2111 - accuracy: 0.9354 - val_loss: 0.2865 - val_accuracy: 0.9151
# Epoch 14/40
# 875/875 [==============================] - 155s 177ms/step - loss: 0.2036 - accuracy: 0.9381 - val_loss: 0.2551 - val_accuracy: 0.9214
# Epoch 15/40
# 875/875 [==============================] - 159s 181ms/step - loss: 0.2041 - accuracy: 0.9375 - val_loss: 0.2321 - val_accuracy: 0.9300
# Epoch 16/40
# 875/875 [==============================] - 147s 168ms/step - loss: 0.1983 - accuracy: 0.9427 - val_loss: 0.2613 - val_accuracy: 0.9241
# Epoch 17/40
# 875/875 [==============================] - 155s 177ms/step - loss: 0.1999 - accuracy: 0.9410 - val_loss: 0.2644 - val_accuracy: 0.9270
# Epoch 18/40
# 875/875 [==============================] - 147s 168ms/step - loss: 0.1767 - accuracy: 0.9495 - val_loss: 0.2902 - val_accuracy: 0.9147
# Epoch 19/40
# 875/875 [==============================] - 147s 168ms/step - loss: 0.1743 - accuracy: 0.9506 - val_loss: 0.2208 - val_accuracy: 0.9310
# Epoch 20/40
# 875/875 [==============================] - 147s 167ms/step - loss: 0.1996 - accuracy: 0.9449 - val_loss: 0.2932 - val_accuracy: 0.9009
# Epoch 21/40
# 875/875 [==============================] - 149s 169ms/step - loss: 0.1848 - accuracy: 0.9504 - val_loss: 0.3379 - val_accuracy: 0.9158
# Epoch 22/40
# 875/875 [==============================] - 125s 142ms/step - loss: 0.1869 - accuracy: 0.9508 - val_loss: 0.2666 - val_accuracy: 0.9271
# Epoch 23/40
# 875/875 [==============================] - 155s 177ms/step - loss: 0.2283 - accuracy: 0.9392 - val_loss: 0.3088 - val_accuracy: 0.9317
# Epoch 24/40
# 875/875 [==============================] - 148s 169ms/step - loss: 0.1782 - accuracy: 0.9524 - val_loss: 0.2531 - val_accuracy: 0.9456
# Epoch 25/40
# 875/875 [==============================] - 148s 168ms/step - loss: 0.1253 - accuracy: 0.9627 - val_loss: 0.2364 - val_accuracy: 0.9321
# Epoch 26/40
# 875/875 [==============================] - 130s 148ms/step - loss: 0.2060 - accuracy: 0.9464 - val_loss: 0.2364 - val_accuracy: 0.9321
# Epoch 27/40
# 875/875 [==============================] - 161s 183ms/step - loss: 0.1643 - accuracy: 0.9548 - val_loss: 0.2912 - val_accuracy: 0.9283
# Epoch 28/40
# 875/875 [==============================] - 148s 168ms/step - loss: 0.1796 - accuracy: 0.9539 - val_loss: 0.3387 - val_accuracy: 0.8865
# Epoch 29/40
# 875/875 [==============================] - 149s 169ms/step - loss: 0.1834 - accuracy: 0.9543 - val_loss: 0.2619 - val_accuracy: 0.9158
# Epoch 30/40
# 875/875 [==============================] - 149s 169ms/step - loss: 0.2223 - accuracy: 0.9431 - val_loss: 0.4569 - val_accuracy: 0.9096
# Epoch 31/40
# 875/875 [==============================] - 149s 170ms/step - loss: 0.1613 - accuracy: 0.9607 - val_loss: 0.2758 - val_accuracy: 0.9220
# Epoch 32/40
# 875/875 [==============================] - 149s 169ms/step - loss: 0.1650 - accuracy: 0.9586 - val_loss: 0.2700 - val_accuracy: 0.9406
# Epoch 33/40
# 875/875 [==============================] - 127s 144ms/step - loss: 0.1914 - accuracy: 0.9553 - val_loss: 0.3155 - val_accuracy: 0.9095
# Epoch 34/40
# 875/875 [==============================] - 150s 171ms/step - loss: 0.1578 - accuracy: 0.9605 - val_loss: 0.5910 - val_accuracy: 0.8618
# Epoch 35/40
# 875/875 [==============================] - 134s 153ms/step - loss: 0.2441 - accuracy: 0.9397 - val_loss: 0.2789 - val_accuracy: 0.9327
# Epoch 36/40
# 875/875 [==============================] - 127s 145ms/step - loss: 0.1725 - accuracy: 0.9561 - val_loss: 0.2952 - val_accuracy: 0.9377
# Epoch 37/40
# 875/875 [==============================] - 150s 170ms/step - loss: 0.1723 - accuracy: 0.9577 - val_loss: 0.2681 - val_accuracy: 0.9087
# Epoch 38/40
# 875/875 [==============================] - 130s 147ms/step - loss: 0.1848 - accuracy: 0.9564 - val_loss: 0.3194 - val_accuracy: 0.9158
# Epoch 39/40
# 875/875 [==============================] - 135s 153ms/step - loss: 0.1986 - accuracy: 0.9519 - val_loss: 0.2635 - val_accuracy: 0.9185
# Epoch 40/40
# 875/875 [==============================] - 151s 171ms/step - loss: 0.1824 - accuracy: 0.9561 - val_loss: 0.3509 - val_accuracy: 0.8947

# %%
# training further might lead to overfitting on train data

# %%
best_model = tf.keras.models.load_model("/kaggle/working/model/cat_breed_classifier_best_model.h5") # rollback to best model

# %%
# model.save(os.path.join('/content/drive/MyDrive/datasets/models','cat_breed_classifier_zf_net_insp_15_epoch.h5')) # saving the model

# %%
fig = plt.figure()
plt.plot(model_history.history['loss'], color='teal', label='loss')
plt.plot(model_history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(model_history.history['accuracy'], color='teal', label='accuracy')
plt.plot(model_history.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ## Model evaluation

# %%
from tensorflow.keras.metrics import Precision, Recall, Accuracy

# %%
pre = Precision()
recall = Recall()
acc = Accuracy()

for batch in test.as_numpy_iterator():
    X, y = batch
    yhat = best_model.predict(X)
    # yhat = tf.nn.softmax(yhat, axis=1) # use when from_logit=True
    # print(yhat)
    yhat = tf.math.argmax(yhat, axis=1)
    pre.update_state(y, yhat)
    recall.update_state(y, yhat)
    acc.update_state(y, yhat)

print(f"Precision is {pre.result()}, Recall is {recall.result()}, Accuracy is {acc.result()}, F1Score is {(2*pre.result()*recall.result())/(pre.result()+recall.result())}")
# Out:
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# Precision is 0.9698051810264587, Recall is 0.9936792850494385, Accuracy is 0.9355000257492065, F1Score is 0.9815970659255981

# %% [markdown]
# ## Plotting the model architecture

# %%
tf.keras.utils.plot_model(
    best_model,
    to_file='own-model.png',
    show_shapes=True,
    show_layer_names=True,
    rankdir='TB',
    dpi=150,
    show_layer_activations=False,
)

# %% [markdown]
# ## Testing completely unseen image data

# %%
model = tf.keras.models.load_model("/kaggle/working/model/cat_breed_classifier_best_model.h5")

# %%
test_path = r"/kaggle/input/cat-breed-dataset/actual_test/actual_test"
test_data = tf.keras.utils.image_dataset_from_directory(test_path,
                                                   batch_size=32,
                                                   class_names=class_list
                                                   )
# Out:
# Found 558 files belonging to 4 classes.

# %%
test_data = test_data.map(lambda x, y: (x/255.0, y))

# %%
pre = Precision()
recall = Recall()
acc = Accuracy()

for batch in test_data.as_numpy_iterator():
    X, y = batch
    yhat = model.predict(X)
    # yhat = tf.nn.softmax(yhat, axis=1) # use when from_logit=True
    # print(yhat)
    yhat = tf.math.argmax(yhat, axis=1)
    pre.update_state(y, yhat)
    recall.update_state(y, yhat)
    acc.update_state(y, yhat)

print(f"Precision is {pre.result()}, Recall is {recall.result()}, Accuracy is {acc.result()}, F1Score is {(2*pre.result()*recall.result())/(pre.result()+recall.result())}")
# Out:
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 376ms/step
# Precision is 0.9200863838195801, Recall is 0.9726027250289917, Accuracy is 0.7885304689407349, F1Score is 0.9456159472465515

# %% [markdown]
# ## Testing on new image

# %%
# test_img = cv2.imread("/content/HD-wallpaper-persian-cat-cat-kitten-little.jpg")
# plt.imshow(cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB))
# plt.show()

# %%
# resize_test = tf.image.resize(test_img, (256,256))
# plt.imshow(resize_test.numpy().astype(int))
# plt.show()

# %%
# resize_test.shape, np.expand_dims(resize_test/255.0, 0).shape

# %%
# yhat = tf.math.argmax(custom_model.predict(np.expand_dims(resize_test/255.0, 0)), axis=1) # keras expects data as batches

# %%
# yhat

# %%
# print("predicted breed is",class_list[yhat[0]])
